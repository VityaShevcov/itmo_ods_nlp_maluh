# %%
import pandas as pd

data = pd.read_csv('data_for_analysis.csv', index_col=0)

# %%
pd.set_option('display.max_colwidth', None)
data.sample(3)
# Out:
#                     id  источник  \
# 11768  SRC023_11962605  Банки_ру
# 2137             71100      2GIS
# 70               71366      2GIS
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   текст
# ...
